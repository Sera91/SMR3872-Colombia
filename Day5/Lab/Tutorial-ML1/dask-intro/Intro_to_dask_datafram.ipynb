# %%
import dask.dataframe as dd
from dask.distributed import Client

# %%
client = Client()
client
# Out:
# /home/serafina/miniconda2/envs/py310-2/lib/python3.10/site-packages/distributed/node.py:183: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 33405 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:35173' processes=4 threads=8, memory=7.68 GiB>

# %%
ddf = dd.read_parquet(
    "s3://dask-data/nyc-taxi/nyc-2015.parquet/part.*.parquet",
    columns=["passenger_count", "tip_amount"],
    storage_options={"anon": True},
)
